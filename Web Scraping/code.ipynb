# %%
from bs4 import BeautifulSoup
import urllib.request
from IPython.display import HTML
import re

# %%
r = urllib.request.urlopen('https://www.trtworld.com/europe/live-blog-russia-will-target-nato-s-patriot-systems-in-ukraine-medvedev-63010').read()
soup = BeautifulSoup(r, "html.parser")
type(soup)

# %%
file = open("scrap_data.csv","w", encoding="utf-8")
print(soup.get_text())
file.write(soup.get_text())
file.flush()
file.close
# Out:
# Live blog: Russia will target NATO's Patriot systems in Ukraine — Medvedev
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ●  Watch Live
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Regions
#
# Americas
# Asia
# Europe
# Middle East
# Africa
# Turkiye
#
#
#
# Sections
#
# Arts & Culture
# Business
# Life
# Sports
#
#
# Opinion
# Magazine
# Topics
#
# Documentaries
#
# A Place Called Pakistan
# Digital Documentaries
# Focal Point
# Off The Grid
# Storyteller
#
#
# Video
#
# More
#
# Perspectives
# Research Centre
# World Citizen
# Jobs
#
#
#
# Watch Live
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SHARE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# News
# Europe
#
#
# Live blog: Russia will target NATO's Patriot systems in Ukraine — Medvedev
#
#
#
# 29 Nov 2022
#
#
#
#
#
#
#
#
#
# ...
